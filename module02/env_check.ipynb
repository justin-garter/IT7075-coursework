# %% [markdown]
# # IT7075 Module 2 — Environment Validation
#
# Notebook companion to `env_check.py`. Confirms the notebook kernel resolves to the
# same virtual environment as the terminal interpreter — the two are selected
# separately in VS Code and are a common source of `ModuleNotFoundError`.

# %%
import sys, platform, os

print(f"Python  {platform.python_version()}")
print(f"Kernel  {sys.executable}")
print(f"Venv    {sys.prefix != sys.base_prefix}")
print(f"Cores   {os.cpu_count()}")
# Out:
# Python  3.13.15
# Kernel  c:\Users\garte\OneDrive - University of Cincinnati\11.Spring2026\Applied AI for Cybersecurity\IT7075-coursework\.venv\Scripts\python.exe
# Venv    True
# Cores   16

# %% [markdown]
# ## Full validation
#
# Runs every check from the script inside the notebook kernel.

# %%
import sys
sys.path.insert(0, ".")
from env_check import main

main()
# Out:
# ============================================================
# IT7075 Module 2 -- Environment Validation
# ============================================================
#
# 1. Interpreter and isolation
# ----------------------------
# [ OK ] Python 3.13.15 (64bit)
#      executable: c:\Users\garte\OneDrive - University of Cincinnati\11.Spring2026\Applied AI for Cybersecurity\IT7075-coursework\.venv\Scripts\python.exe
# [ OK ] Running inside a virtual environment
#      venv root:  c:\Users\garte\OneDrive - University of Cincinnati\11.Spring2026\Applied AI for Cybersecurity\IT7075-coursework\.venv
#
# 2. Compute inventory
# --------------------
# [ OK ] Platform:  Windows 11
# [ OK ] Processor: AMD64 Family 25 Model 97 Stepping 2, AuthenticAMD
# [ OK ] Logical cores: 16
# [ OK ] Total RAM: 31.1 GiB
# [ OK ] torch 2.11.0+cu128
# [ OK ] torch.cuda.is_available() -> True
#      device 0: NVIDIA GeForce RTX 5070
#      CUDA build: 12.8
# [ OK ] nvidia-smi present on PATH -- run it separately for driver detail
#
# 3. Required packages
# --------------------
# [ OK ] python-dotenv
# [ OK ] openai
# [ OK ] anthropic
# [ OK ] jupyter
#
# 4. Credentials (values never printed)
# -------------------------------------
# [ OK ] .env found: .env (in c:\Users\garte\OneDrive - University of Cincinnati\11.Spring2026\Applied AI for Cybersecurity\IT7075-coursework)
# [ OK ] OPENAI_API_KEY: loaded, 164 chars (value not shown)
# [WARN] ANTHROPIC_API_KEY: not set
#
# ============================================================
# Interpreter isolation: PASS
# ============================================================
# 0
